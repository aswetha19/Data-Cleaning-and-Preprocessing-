# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\pslas\OneDrive\Desktop\Day-1.csv")
df
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589980e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262960e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679510e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841190e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572130e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596270e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557660e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213490e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775120e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589980e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262960e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679510e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841190e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572130e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596270e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557660e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213490e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775120e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df['Gender'] = df['Gender'].str.lower().str.strip()
df['Gender'].replace({'f':'female','m':'male'}, inplace=True)
df
# Out:
# C:\Users\pslas\AppData\Local\Temp\ipykernel_15788\1699283170.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].replace({'f':'female','m':'male'}, inplace=True)
#            PatientId  AppointmentID  Gender          ScheduledDay  \
# 0       2.987250e+13        5642903  female  2016-04-29T18:38:08Z
# 1       5.589980e+14        5642503    male  2016-04-29T16:08:27Z
# 2       4.262960e+12        5642549  female  2016-04-29T16:19:04Z
# 3       8.679510e+11        5642828  female  2016-04-29T17:29:31Z
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_', regex=False)

# %%
df['scheduledday'] = pd.to_datetime(df['scheduledday'], errors='coerce')
df['appointmentday'] = pd.to_datetime(df['appointmentday'], errors='coerce')
df
# Out:
#            patientid  appointmentid  gender              scheduledday  \
# 0       2.987250e+13        5642903  female 2016-04-29 18:38:08+00:00
# 1       5.589980e+14        5642503    male 2016-04-29 16:08:27+00:00
# 2       4.262960e+12        5642549  female 2016-04-29 16:19:04+00:00
# 3       8.679510e+11        5642828  female 2016-04-29 17:29:31+00:00
# 4       8.841190e+12        5642494  female 2016-04-29 16:07:23+00:00
# ...              ...            ...     ...                       ...
# 110522  2.572130e+12        5651768  female 2016-05-03 09:15:35+00:00
# 110523  3.596270e+12        5650093  female 2016-05-03 07:27:33+00:00
# 110524  1.557660e+13        5630692  female 2016-04-27 16:03:52+00:00
# 110525  9.213490e+13        5630323  female 2016-04-27 15:09:23+00:00
# 110526  3.775120e+14        5629448  female 2016-04-27 13:30:56+00:00
#
#                   appointmentday  age      neighbourhood  scholarship  \
# ...

# %%
df['patientid'] = df['patientid'].astype('int64').astype(str)
df
# Out:
#               patientid  appointmentid  gender              scheduledday  \
# 0        29872500000000        5642903  female 2016-04-29 18:38:08+00:00
# 1       558998000000000        5642503    male 2016-04-29 16:08:27+00:00
# 2         4262960000000        5642549  female 2016-04-29 16:19:04+00:00
# 3          867951000000        5642828  female 2016-04-29 17:29:31+00:00
# 4         8841190000000        5642494  female 2016-04-29 16:07:23+00:00
# ...                 ...            ...     ...                       ...
# 110522    2572130000000        5651768  female 2016-05-03 09:15:35+00:00
# 110523    3596270000000        5650093  female 2016-05-03 07:27:33+00:00
# 110524   15576600000000        5630692  female 2016-04-27 16:03:52+00:00
# 110525   92134900000000        5630323  female 2016-04-27 15:09:23+00:00
# 110526  377512000000000        5629448  female 2016-04-27 13:30:56+00:00
#
#                   appointmentday  age      neighbourhood  scholarship  \
# ...

# %%
df['age'] = df['age'].astype('int64')

# %%
df.to_csv(r"C:\Users\pslas\OneDrive\Desktop\Day-1.csv",index=False)
df
# Out:
#               patientid  appointmentid  gender              scheduledday  \
# 0        29872500000000        5642903  female 2016-04-29 18:38:08+00:00
# 1       558998000000000        5642503    male 2016-04-29 16:08:27+00:00
# 2         4262960000000        5642549  female 2016-04-29 16:19:04+00:00
# 3          867951000000        5642828  female 2016-04-29 17:29:31+00:00
# 4         8841190000000        5642494  female 2016-04-29 16:07:23+00:00
# ...                 ...            ...     ...                       ...
# 110522    2572130000000        5651768  female 2016-05-03 09:15:35+00:00
# 110523    3596270000000        5650093  female 2016-05-03 07:27:33+00:00
# 110524   15576600000000        5630692  female 2016-04-27 16:03:52+00:00
# 110525   92134900000000        5630323  female 2016-04-27 15:09:23+00:00
# 110526  377512000000000        5629448  female 2016-04-27 13:30:56+00:00
#
#                   appointmentday  age      neighbourhood  scholarship  \
# ...

# %%
df = df[(df['age'] >= 0) & (df['age'] <= 120)]
df
# Out:
#               patientid  appointmentid  gender              scheduledday  \
# 0        29872500000000        5642903  female 2016-04-29 18:38:08+00:00
# 1       558998000000000        5642503    male 2016-04-29 16:08:27+00:00
# 2         4262960000000        5642549  female 2016-04-29 16:19:04+00:00
# 3          867951000000        5642828  female 2016-04-29 17:29:31+00:00
# 4         8841190000000        5642494  female 2016-04-29 16:07:23+00:00
# ...                 ...            ...     ...                       ...
# 110522    2572130000000        5651768  female 2016-05-03 09:15:35+00:00
# 110523    3596270000000        5650093  female 2016-05-03 07:27:33+00:00
# 110524   15576600000000        5630692  female 2016-04-27 16:03:52+00:00
# 110525   92134900000000        5630323  female 2016-04-27 15:09:23+00:00
# 110526  377512000000000        5629448  female 2016-04-27 13:30:56+00:00
#
#                   appointmentday  age      neighbourhood  scholarship  \
# ...

# %%
df['neighbourhood'] = df['neighbourhood'].str.strip().str.title()
df
# Out:
# C:\Users\pslas\AppData\Local\Temp\ipykernel_15788\3514427839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['neighbourhood'] = df['neighbourhood'].str.strip().str.title()
#               patientid  appointmentid  gender              scheduledday  \
# 0        29872500000000        5642903  female 2016-04-29 18:38:08+00:00
# 1       558998000000000        5642503    male 2016-04-29 16:08:27+00:00
# 2         4262960000000        5642549  female 2016-04-29 16:19:04+00:00
# 3          867951000000        5642828  female 2016-04-29 17:29:31+00:00
# 4         8841190000000        5642494  female 2016-04-29 16:07:23+00:00
# ...                 ...            ...     ...                       ...
# ...

# %%
df['scheduled_day'] = df['scheduledday'].dt.day_name()
df['waiting_days'] = (df['appointmentday'] - df['scheduledday']).dt.days
df
# Out:
# C:\Users\pslas\AppData\Local\Temp\ipykernel_15788\2451542453.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scheduled_day'] = df['scheduledday'].dt.day_name()
# C:\Users\pslas\AppData\Local\Temp\ipykernel_15788\2451542453.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['waiting_days'] = (df['appointmentday'] - df['scheduledday']).dt.days
#               patientid  appointmentid  gender              scheduledday  \
# ...
